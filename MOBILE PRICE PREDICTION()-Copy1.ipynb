# %% [markdown]
# # Mobile Price Prediction

# %% [markdown]
# ## Description of data
#
# #####  In this data set we have 20 different features of a mobile phone which effect the price .
# #####  Here we have Two different Data Sets
# ###### > Training Data Set for Building the Model
# ###### > Testing Data set  for Predicting the Price

# %% [markdown]
# ###      Description of Features
#         1> battery_power : Battery Backup measured in mAh
#
#         2> blue : Has Bluetooth or not
#
#         3> clock_speed : the speed at which microprocessor executes instructions
#
#         4> dual_sim : Has dual sim support or not
#
#         5> fc : Front Camera megapixels
#
#         6> four_g  : Has 4G or not
#
#         7> int_memory : Internal Memory in Gigabytes
#
#         8> m_dep : Mobile Depth in cm
#
#         9> mobile_wt : Weight of mobile phone
#
#         10> n_cores : Number of cores of the processor
#
#         11> pc : Primary Camera megapixels
#
#         12> px_height : Pixel Resolution Height
#
#         13> px_width  : Pixel Resolution Width
#
#         14> ram  : Random Access Memory in MegaBytes
#
#         15> sc_h : Screen Height of mobile in cm
#
#         16> sc_w : Screen Width of mobile in cm
#
#         17> talk_time : the longest time that a single battery charge will last
#
#         18> three_g : Has 3G or not
#
#         19> touch_screen : Has touch screen or not
#
#         20> wifi : Has wifi or not
#
#         21> price_range : This is the target variable with a value of
#                       0(low cost), 1(medium cost), 2(high cost) and 3(very high cost).

# %% [markdown]
# ###   > Load Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### > Load Data

# %%
#loading training data

train_data=pd.read_csv('C:/Users/kadam/Downloads/mobile_price_pred/train.csv')

#loading testing data

test_data=pd.read_csv('C:/Users/kadam/Downloads/mobile_price_pred/test.csv')

# %%
train_data.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
# 5        164        1  ...       1004      1654  1067    17     1         10
# 6        139        8  ...        381      1018  3220    13     8         18
# 7        187        4  ...        512      1149   700    16     3          5
# 8        174        7  ...        386       836  1099    17     1         20
# 9         93        5  ...       1137      1224   513    19    10         12
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
# 5        1             0     0            1
# 6        1             0     1            3
# 7        1             1     1            0
# 8        1             0     0            0
# 9        1             0     0            0
#
# [10 rows x 21 columns]

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# ###  > Heat Map

# %%
data = train_data

X = data.drop(['price_range'],axis=1)                     #independent columns
y = data['price_range']                                   #target column i.e price range

#get correlations of each features in dataset

corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))

#plot heat map

g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# ### > Line Plot

# %%
sns.set(style='darkgrid')
sns.lineplot(x = 'price_range', y = 'ram', data = train_data);
plt.text (x= 4, y=3200 , s = "Price vs Ram",fontsize = 30, weight = 'bold');

# %%
sns.set(style='darkgrid')
sns.lineplot(x = 'price_range', y = 'px_width', data = train_data);
plt.text (x= 4, y=1400 , s = "Price vs Pixel",fontsize = 30, weight = 'bold');

# %%
sns.set(style='darkgrid')
sns.lineplot(x = 'price_range', y = 'battery_power', data = train_data);
plt.text (x= 4, y=1400 , s = "Price vs Battery",fontsize = 30, weight = 'bold');

# %%
sns.relplot(x = 'ram', y = 'px_width',hue = 'battery_power',col="price_range" , data = train_data);

# %% [markdown]
# ### > Building Model

# %%
print(train_data.shape)
# Out:
# (2000, 21)

# %%
train_data.keys()
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
# battery_power    2000 non-null int64
# blue             2000 non-null int64
# clock_speed      2000 non-null float64
# dual_sim         2000 non-null int64
# fc               2000 non-null int64
# four_g           2000 non-null int64
# int_memory       2000 non-null int64
# m_dep            2000 non-null float64
# mobile_wt        2000 non-null int64
# n_cores          2000 non-null int64
# pc               2000 non-null int64
# px_height        2000 non-null int64
# px_width         2000 non-null int64
# ram              2000 non-null int64
# sc_h             2000 non-null int64
# sc_w             2000 non-null int64
# talk_time        2000 non-null int64
# three_g          2000 non-null int64
# touch_screen     2000 non-null int64
# wifi             2000 non-null int64
# price_range      2000 non-null int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
train_data.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %% [markdown]
# ### > Spliting Data into Features and Labels

# %%
Features=train_data.drop( columns = ['price_range', "wifi" , "blue" , "clock_speed" , "dual_sim", "m_dep","mobile_wt", "talk_time" , "three_g" , "touch_screen" ,"wifi"])

# %%
Features.head()
# Out:
#    battery_power  fc  four_g  int_memory  n_cores  pc  px_height  px_width  \
# 0            842   1       0           7        2   2         20       756
# 1           1021   0       1          53        3   6        905      1988
# 2            563   2       1          41        5   6       1263      1716
# 3            615   0       0          10        6   9       1216      1786
# 4           1821  13       1          44        2  14       1208      1212
#
#     ram  sc_h  sc_w
# 0  2549     9     7
# 1  2631    17     3
# 2  2603    11     2
# 3  2769    16     8
# 4  1411     8     2

# %%
Label=train_data['price_range']

# %%
Label.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(Features,Label,random_state=4,test_size=0.2)

# %% [markdown]
# ###  > Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.metrics import mean_squared_error
predict=lr.predict(x_test)
mean_squared_error(predict,y_test)
# Out:
# 0.09952438094076782

# %% [markdown]
# ### > For finding Accuracy

# %%
acc=lr.score(x_test,y_test)*100
print("Accuracy of the Model is = ", acc ,"%")
# Out:
# Accuracy of the Model is =  92.40094251493773 %

# %% [markdown]
# ### > Knn

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %% [markdown]
# ### > For inding Accuracy & MSE

# %%
knn_predict=knn.predict(x_test)
print("Accuracy of Model is :" , knn.score(x_test,y_test)*100,"%")
print("Mean Square Error is :" , mean_squared_error(knn_predict,y_test)*100 ,"%")
# Out:
# Accuracy of Model is : 95.0 %
# Mean Square Error is : 5.0 %

# %% [markdown]
# ### > Predicting the price

# %%
test_data.head(10)
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
# 5   6           1464     1          2.9         1   5       1          50
# 6   7           1718     0          2.4         0   1       0          47
# 7   8            833     0          2.4         1   0       0          62
# 8   9           1111     1          2.9         1   9       1          25
# 9  10           1520     0          0.5         0   1       0          25
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
# 5    0.8        198  ...   9        569       939  3506    10     7
# 6    1.0        156  ...   3       1283      1374  3873    14     2
# 7    0.8        111  ...   2       1312      1880  1495     7     2
# 8    0.6        101  ...  19        556       876  3485    11     9
# 9    0.5        171  ...  20         52      1009   651     6     0
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
# 3          7        1             1     0
# 4          7        1             0     1
# 5          3        1             1     1
# 6         10        0             0     0
# 7         18        0             1     1
# 8         10        1             1     0
# 9          5        1             0     1
#
# [10 rows x 21 columns]

# %%
test=test_data.drop( columns = ['id', "wifi" , "blue" , "clock_speed" , "dual_sim", "m_dep","mobile_wt", "talk_time" , "three_g" , "touch_screen" ,"wifi"])

# %%
test.keys()
# Out:
# Index(['battery_power', 'fc', 'four_g', 'int_memory', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w'],
#       dtype='object')

# %%
train_data.keys()
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %% [markdown]
# ### > Predicting the "Price_range"

# %%
test.keys()
# Out:
# Index(['battery_power', 'fc', 'four_g', 'int_memory', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w'],
#       dtype='object')

# %%
test_predict=knn.predict(test)

# %%
print(test_predict)
# Out:
# [3 3 2 3 1 3 3 1 3 0 3 3 0 0 2 0 2 1 3 2 1 3 1 1 3 0 2 0 3 0 2 0 3 0 0 1 3
#  1 2 1 1 2 0 0 0 1 0 3 1 2 1 0 3 0 3 1 3 1 1 3 3 2 0 2 0 1 1 3 1 2 1 2 2 3
#  3 0 2 0 2 3 0 3 3 0 3 0 3 1 3 0 1 2 2 1 2 2 0 2 1 2 1 0 0 3 0 2 0 1 2 3 3
#  3 1 3 3 3 3 1 3 0 0 3 2 1 2 0 3 2 3 1 0 2 1 1 3 1 1 0 3 2 1 2 1 2 2 3 3 2
#  2 3 2 3 1 0 3 2 3 3 3 3 2 2 3 3 3 3 1 0 3 0 0 0 2 1 0 1 0 0 1 2 1 0 0 1 1
#  2 2 1 0 0 0 1 0 3 1 0 2 2 2 3 1 2 2 2 3 2 2 1 0 0 1 2 0 2 3 3 0 2 0 3 2 2
#  3 1 0 1 0 3 0 1 0 2 2 1 2 0 3 0 3 1 2 0 0 2 1 3 3 3 1 1 3 0 0 2 3 3 1 3 1
#  1 3 2 1 2 3 3 3 1 0 0 2 3 1 1 3 2 0 3 0 0 3 0 0 3 2 3 3 2 1 3 3 2 3 1 2 1
#  2 0 2 3 1 0 0 3 0 3 0 1 2 0 2 3 1 3 2 2 1 2 0 0 0 1 3 2 0 0 0 3 2 0 2 3 1
#  2 2 2 3 1 3 3 2 2 2 3 3 0 3 1 3 1 3 1 3 3 0 1 0 3 1 3 2 3 0 0 0 0 2 0 0 2
#  2 1 2 2 2 0 1 0 0 3 2 0 3 1 2 2 1 2 3 1 1 2 2 1 2 0 1 1 0 3 2 1 0 1 0 0 1
#  1 0 0 0 2 2 3 2 3 0 3 0 3 0 1 1 1 1 0 3 2 3 3 1 3 1 3 1 3 2 0 1 2 1 1 0 0
#  0 1 2 1 0 3 2 0 2 3 0 0 3 1 1 0 3 2 3 0 3 0 2 3 3 3 0 2 0 2 3 0 1 1 0 0 1
#  1 1 3 3 3 2 3 1 2 2 2 3 3 2 0 2 1 2 2 1 0 2 2 0 0 0 3 1 1 2 2 2 0 3 0 2 2
#  0 3 0 2 3 0 1 1 3 3 1 1 2 3 2 0 2 1 2 0 3 3 1 2 2 2 3 0 1 2 3 1 3 2 3 1 1
#  0 0 3 1 0 3 2 3 2 0 3 3 3 2 3 3 1 2 0 2 3 3 1 0 1 1 2 2 2 0 0 2 2 3 2 0 2
#  1 3 3 0 1 3 0 2 1 0 0 0 2 1 0 1 1 2 2 0 2 2 1 0 3 0 0 3 2 0 0 0 0 0 3 0 3
#  1 3 2 1 3 3 0 1 0 3 2 2 2 0 3 0 2 0 2 0 0 1 1 1 2 1 3 1 3 2 2 1 3 2 0 1 2
#  0 3 3 0 2 1 1 2 0 3 2 0 3 2 3 0 0 3 0 2 2 3 2 2 2 2 1 2 3 0 1 1 1 2 1 0 0
#  1 0 0 3 1 1 2 0 0 1 1 3 0 3 2 3 0 0 1 2 1 1 0 1 2 0 1 1 0 0 3 3 0 3 1 2 3
#  0 1 0 2 2 0 3 1 0 3 1 1 0 3 3 3 2 3 0 3 2 0 0 0 3 3 2 0 1 1 3 0 0 3 2 0 3
#  1 2 1 1 1 3 1 1 1 2 0 0 1 2 0 2 0 0 0 0 2 3 3 3 0 1 2 2 1 0 0 2 1 0 2 0 2
#  2 2 1 2 0 2 1 3 0 0 3 2 3 0 0 2 3 3 1 2 2 1 0 0 2 3 0 3 0 0 0 2 2 1 2 0 3
#  2 1 2 3 3 0 1 1 2 1 2 2 0 1 3 1 1 3 0 2 3 1 1 1 1 3 2 0 2 3 0 2 3 2 2 2 3
#  2 0 1 2 0 2 1 1 2 2 2 1 2 1 1 1 3 1 0 1 2 3 1 0 0 2 2 2 3 0 3 3 2 1 3 0 1
#  3 1 2 1 1 3 2 0 3 0 2 3 0 2 1 2 3 1 0 2 3 1 0 1 1 2 1 2 0 2 2 0 2 3 2 3 0
#  2 1 1 2 2 3 3 0 2 1 2 1 3 0 0 3 0 1 0 0 3 3 2 0 0 0 0 3 2 3 3 0 0 2 1 0 2
#  2]

# %%
test_data['price_range']=test_predict
test_data.head()
# Out:
#     id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# id
# 1    1           1043     1          1.8         1  14       0           5
# 2    2            841     1          0.5         1   4       1          61
# 3    3           1807     1          2.8         0   1       0          27
# 4    4           1546     0          0.5         1  18       1          25
# 5    5           1434     0          1.4         0  11       1          49
#
#     m_dep  mobile_wt  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# id                    ...
# 1     0.1        193  ...        226      1412  3476    12     7          2
# 2     0.8        191  ...        746       857  3895     6     0          7
# 3     0.9        186  ...       1270      1366  2396    17    10         10
# 4     0.5         96  ...        295      1752  3893    10     0          7
# 5     0.5        108  ...        749       810  1773    15     8          7
#
#     three_g  touch_screen  wifi  price_range
# id
# 1         0             1     0            3
# 2         1             0     0            3
# 3         0             1     1            2
# 4         1             1     0            3
# 5         1             0     1            1
#
# [5 rows x 22 columns]
